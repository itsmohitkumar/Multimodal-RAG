# %%
# <a href="https://colab.research.google.com/github/run-llama/llama_index/blob/main/docs/docs/examples/multi_modal/multi_modal_retrieval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# 
# # Multi-Modal Retrieval using Groq Text Embedding and CLIP Image Embedding for Wikipedia Articles
# 
# In this notebook, we demonstrate how to build a multi-modal retrieval system using LlamaIndex with Groq text embeddings and CLIP image embeddings.
# 
# **Wikipedia Text Embedding Index:** Generate Groq text embeddings for texts.
# 
# **Wikipedia Images Embedding Index:** [CLIP](https://github.com/openai/CLIP) embeddings from OpenAI for images.
# 
# **Query Encoder:**
# - Encode query text for the text index using Groq embeddings.
# - Encode query text for the image index using CLIP embeddings.
# 
# **Framework:** [LlamaIndex](https://github.com/run-llama/llama_index)
# 
# **Steps:**
# 1. Download texts and images from Wikipedia articles.
# 2. Build a text index for the vector store using Groq embeddings.
# 3. Build an image index for the vector store using CLIP embeddings.
# 4. Retrieve relevant text and images simultaneously using different query encoding embeddings and vector stores.

# %%
# Step 1: Install Required Packages
# %pip install -q llama-index-vector-stores-qdrant
# Out:
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the '/Users/taurangela/Desktop/Github/Multimodal-RAG/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install llama_index ftfy regex tqdm
# %pip install git+https://github.com/openai/CLIP.git
# %pip install torch torchvision
# %pip install matplotlib scikit-image
# %pip install -U qdrant_client
# %pip install requests
# Out:
# Collecting llama_index
#   Downloading llama_index-0.11.8-py3-none-any.whl (6.8 kB)
# Collecting ftfy
#   Downloading ftfy-6.2.3-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 KB 400.3 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: regex in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (2024.9.11)
# Requirement already satisfied: tqdm in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (4.66.5)
# Collecting llama-index-agent-openai<0.4.0,>=0.3.1
#   Downloading llama_index_agent_openai-0.3.1-py3-none-any.whl (13 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48
#   Downloading llama_index_legacy-0.9.48.post3-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: nltk>3.8.1 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama_index) (3.9.1)
# Collecting llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0
#   Downloading llama_index_multi_modal_llms_openai-0.2.0-py3-none-any.whl (5.9 kB)
# Collecting llama-index-cli<0.4.0,>=0.3.1
#   Downloading llama_index_cli-0.3.1-py3-none-any.whl (27 kB)
# Collecting llama-index-program-openai<0.3.0,>=0.2.0
#   Downloading llama_index_program_openai-0.2.0-py3-none-any.whl (5.3 kB)
# Collecting llama-index-readers-file<0.3.0,>=0.2.0
#   Downloading llama_index_readers_file-0.2.1-py3-none-any.whl (38 kB)
# Collecting llama-index-embeddings-openai<0.3.0,>=0.2.4
#   Downloading llama_index_embeddings_openai-0.2.4-py3-none-any.whl (6.1 kB)
# Collecting llama-index-llms-openai<0.3.0,>=0.2.3
#   Downloading llama_index_llms_openai-0.2.5-py3-none-any.whl (12 kB)
# Collecting llama-index-readers-llama-parse>=0.3.0
#   Downloading llama_index_readers_llama_parse-0.3.0-py3-none-any.whl (2.5 kB)
# Collecting llama-index-indices-managed-llama-cloud>=0.3.0
#   Downloading llama_index_indices_managed_llama_cloud-0.3.0-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.8 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama_index) (0.11.8)
# Collecting llama-index-question-gen-openai<0.3.0,>=0.2.0
#   Downloading llama_index_question_gen_openai-0.2.0-py3-none-any.whl (2.9 kB)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from ftfy) (0.2.13)
# Collecting openai>=1.14.0
#   Downloading openai-1.45.0-py3-none-any.whl (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.1/374.1 KB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (2.9.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (6.0.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (0.9.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (0.7.0)
# Requirement already satisfied: numpy<2.0.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (1.26.4)
# Requirement already satisfied: dataclasses-json in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (0.6.7)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (2.0.34)
# Requirement already satisfied: networkx>=3.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (3.3)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (1.0.8)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (1.2.14)
# Requirement already satisfied: httpx in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (0.27.2)
# Requirement already satisfied: pillow>=9.0.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (10.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (4.12.2)
# Requirement already satisfied: wrapt in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (1.16.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (1.6.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (3.10.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (2024.9.0)
# Requirement already satisfied: requests>=2.31.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.8->llama_index) (8.5.0)
# Collecting llama-cloud>=0.0.11
#   Downloading llama_cloud-0.0.17-py3-none-any.whl (187 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.4/187.4 KB 2.8 MB/s eta 0:00:0000:01
# Collecting pandas
#   Using cached pandas-2.2.2-cp310-cp310-macosx_10_9_x86_64.whl (12.6 MB)
# Collecting striprtf<0.0.27,>=0.0.26
#   Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Collecting beautifulsoup4<5.0.0,>=4.12.3
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Collecting pypdf<5.0.0,>=4.0.1
#   Downloading pypdf-4.3.1-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 KB 9.6 MB/s eta 0:00:00
# Collecting llama-parse>=0.5.0
#   Downloading llama_parse-0.5.5-py3-none-any.whl (10 kB)
# Requirement already satisfied: click in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from nltk>3.8.1->llama_index) (8.1.7)
# Requirement already satisfied: joblib in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from nltk>3.8.1->llama_index) (1.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.8->llama_index) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.8->llama_index) (6.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.8->llama_index) (1.4.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.8->llama_index) (24.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.8->llama_index) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.8->llama_index) (4.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.8->llama_index) (2.4.0)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# Requirement already satisfied: sniffio in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.8->llama_index) (1.3.1)
# Requirement already satisfied: idna in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.8->llama_index) (3.8)
# Requirement already satisfied: anyio in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.8->llama_index) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.8->llama_index) (1.0.5)
# Requirement already satisfied: certifi in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.8->llama_index) (2024.8.30)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.8->llama_index) (0.14.0)
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting jiter<1,>=0.4.0
#   Downloading jiter-0.5.0-cp310-cp310-macosx_10_12_x86_64.whl (284 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.1/284.1 KB 6.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pydantic-core==2.23.3 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.8->llama_index) (2.23.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.8->llama_index) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.8->llama_index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.8->llama_index) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.8->llama_index) (3.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.8->llama_index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.8->llama_index) (3.22.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (2.9.0.post0)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.8->llama_index) (1.2.2)
# Requirement already satisfied: packaging>=17.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.8->llama_index) (24.1)
# Requirement already satisfied: six>=1.5 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama_index) (1.16.0)
# Installing collected packages: striprtf, pytz, tzdata, soupsieve, pypdf, jiter, ftfy, distro, pandas, beautifulsoup4, openai, llama-cloud, llama-index-legacy, llama-parse, llama-index-readers-file, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-llms-openai, llama-index-agent-openai, llama-index-program-openai, llama-index-question-gen-openai, llama-index-multi-modal-llms-openai, llama-index-cli, llama_index
# Successfully installed beautifulsoup4-4.12.3 distro-1.9.0 ftfy-6.2.3 jiter-0.5.0 llama-cloud-0.0.17 llama-index-agent-openai-0.3.1 llama-index-cli-0.3.1 llama-index-embeddings-openai-0.2.4 llama-index-indices-managed-llama-cloud-0.3.0 llama-index-legacy-0.9.48.post3 llama-index-llms-openai-0.2.5 llama-index-multi-modal-llms-openai-0.2.0 llama-index-program-openai-0.2.0 llama-index-question-gen-openai-0.2.0 llama-index-readers-file-0.2.1 llama-index-readers-llama-parse-0.3.0 llama-parse-0.5.5 llama_index-0.11.8 openai-1.45.0 pandas-2.2.2 pypdf-4.3.1 pytz-2024.2 soupsieve-2.6 striprtf-0.0.26 tzdata-2024.1
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the '/Users/taurangela/Desktop/Github/Multimodal-RAG/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /private/var/folders/xw/5bq269q12p38ws8zd1gwynlh0000gn/T/pip-req-build-l502aejv
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /private/var/folders/xw/5bq269q12p38ws8zd1gwynlh0000gn/T/pip-req-build-l502aejv
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ftfy in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from clip==1.0) (6.2.3)
# Requirement already satisfied: packaging in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from clip==1.0) (24.1)
# Requirement already satisfied: regex in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from clip==1.0) (2024.9.11)
# Requirement already satisfied: tqdm in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from clip==1.0) (4.66.5)
# Collecting torch
#   Downloading torch-2.2.2-cp310-none-macosx_10_9_x86_64.whl (150.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.8/150.8 MB 1.4 MB/s eta 0:00:0000:0100:01
# Collecting torchvision
#   Downloading torchvision-0.17.2-cp310-cp310-macosx_10_13_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 13.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from ftfy->clip==1.0) (0.2.13)
# Collecting filelock
#   Using cached filelock-3.16.0-py3-none-any.whl (16 kB)
# Collecting jinja2
#   Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Collecting sympy
#   Downloading sympy-1.13.2-py3-none-any.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 16.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: fsspec in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from torch->clip==1.0) (2024.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from torch->clip==1.0) (4.12.2)
# Requirement already satisfied: networkx in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from torch->clip==1.0) (3.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from torchvision->clip==1.0) (10.4.0)
# Requirement already satisfied: numpy in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from torchvision->clip==1.0) (1.26.4)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.5-cp310-cp310-macosx_10_9_x86_64.whl (14 kB)
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 16.0 MB/s eta 0:00:00
# Using legacy 'setup.py install' for clip, since package 'wheel' is not installed.
# Installing collected packages: mpmath, sympy, MarkupSafe, filelock, jinja2, torch, torchvision, clip
#   Running setup.py install for clip ... done
# Successfully installed MarkupSafe-2.1.5 clip-1.0 filelock-3.16.0 jinja2-3.1.4 mpmath-1.3.0 sympy-1.13.2 torch-2.2.2 torchvision-0.17.2
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the '/Users/taurangela/Desktop/Github/Multimodal-RAG/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: torchvision in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (0.17.2)
# Requirement already satisfied: fsspec in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from torch) (2024.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: filelock in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from torch) (3.16.0)
# Requirement already satisfied: jinja2 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: numpy in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the '/Users/taurangela/Desktop/Github/Multimodal-RAG/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Collecting matplotlib
#   Using cached matplotlib-3.9.2-cp310-cp310-macosx_10_12_x86_64.whl (7.9 MB)
# Collecting scikit-image
#   Downloading scikit_image-0.24.0-cp310-cp310-macosx_10_9_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 6.3 MB/s eta 0:00:0000:0100:01
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.53.1-cp310-cp310-macosx_10_9_universal2.whl (2.8 MB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.7-cp310-cp310-macosx_10_9_x86_64.whl (65 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.23 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.0-cp310-cp310-macosx_10_9_x86_64.whl (265 kB)
# Collecting scipy>=1.9
#   Downloading scipy-1.14.1-cp310-cp310-macosx_10_13_x86_64.whl (39.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.1/39.1 MB 8.3 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: networkx>=2.8 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from scikit-image) (3.3)
# Collecting imageio>=2.33
#   Using cached imageio-2.35.1-py3-none-any.whl (315 kB)
# Collecting tifffile>=2022.8.12
#   Downloading tifffile-2024.8.30-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 KB 1.9 MB/s eta 0:00:0000:01
# Collecting lazy-loader>=0.4
#   Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Requirement already satisfied: six>=1.5 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: tifffile, scipy, pyparsing, lazy-loader, kiwisolver, imageio, fonttools, cycler, contourpy, scikit-image, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.53.1 imageio-2.35.1 kiwisolver-1.4.7 lazy-loader-0.4 matplotlib-3.9.2 pyparsing-3.1.4 scikit-image-0.24.0 scipy-1.14.1 tifffile-2024.8.30
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the '/Users/taurangela/Desktop/Github/Multimodal-RAG/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: qdrant_client in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (1.11.1)
# Requirement already satisfied: grpcio-tools>=1.41.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from qdrant_client) (1.66.1)
# Requirement already satisfied: grpcio>=1.41.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from qdrant_client) (1.66.1)
# Requirement already satisfied: numpy>=1.21 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from qdrant_client) (1.26.4)
# Requirement already satisfied: httpx[http2]>=0.20.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from qdrant_client) (0.27.2)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from qdrant_client) (2.2.3)
# Requirement already satisfied: pydantic>=1.10.8 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from qdrant_client) (2.9.1)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from qdrant_client) (2.10.1)
# Requirement already satisfied: protobuf<6.0dev,>=5.26.1 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from grpcio-tools>=1.41.0->qdrant_client) (5.28.1)
# Requirement already satisfied: setuptools in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from grpcio-tools>=1.41.0->qdrant_client) (58.1.0)
# Requirement already satisfied: idna in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from httpx[http2]>=0.20.0->qdrant_client) (3.8)
# Requirement already satisfied: certifi in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from httpx[http2]>=0.20.0->qdrant_client) (2024.8.30)
# Requirement already satisfied: anyio in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from httpx[http2]>=0.20.0->qdrant_client) (4.4.0)
# Requirement already satisfied: sniffio in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from httpx[http2]>=0.20.0->qdrant_client) (1.3.1)
# Requirement already satisfied: httpcore==1.* in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from httpx[http2]>=0.20.0->qdrant_client) (1.0.5)
# Requirement already satisfied: h2<5,>=3 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from httpx[http2]>=0.20.0->qdrant_client) (4.1.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from httpcore==1.*->httpx[http2]>=0.20.0->qdrant_client) (0.14.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from pydantic>=1.10.8->qdrant_client) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from pydantic>=1.10.8->qdrant_client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from pydantic>=1.10.8->qdrant_client) (2.23.3)
# Requirement already satisfied: hpack<5,>=4.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant_client) (4.0.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant_client) (6.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from anyio->httpx[http2]>=0.20.0->qdrant_client) (1.2.2)
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the '/Users/taurangela/Desktop/Github/Multimodal-RAG/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from requests) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from requests) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/taurangela/Desktop/Github/Multimodal-RAG/env/lib/python3.10/site-packages (from requests) (2.2.3)
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the '/Users/taurangela/Desktop/Github/Multimodal-RAG/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -qU langchain-groq python-dotenv
# Out:
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the '/Users/taurangela/Desktop/Github/Multimodal-RAG/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Step 2: Load and Download Multi-Modal Datasets Including Texts and Images from Wikipedia

from pathlib import Path
import requests

wiki_titles = ["RoboCop", "Labour Party (UK)", "SpaceX", "OpenAI"]
data_path = Path("data_wiki")

data_path.mkdir(parents=True, exist_ok=True)

for title in wiki_titles:
    response = requests.get(
        "https://en.wikipedia.org/w/api.php",
        params={"action": "query", "format": "json", "titles": title, "prop": "extracts", "explaintext": True},
    ).json()
    page = next(iter(response["query"]["pages"].values()))
    wiki_text = page["extract"]

    with open(data_path / f"{title}.txt", "w") as fp:
        fp.write(wiki_text)

# %%
# Step 3: Parse Wikipedia Images and Load into Local Folder

import wikipedia
import urllib.request
import os

image_path = Path("data_wiki")
image_uuid = 0
image_metadata_dict = {}
MAX_IMAGES_PER_WIKI = 30

image_path.mkdir(parents=True, exist_ok=True)

for title in wiki_titles:
    images_per_wiki = 0
    try:
        page_py = wikipedia.page(title)
        list_img_urls = page_py.images
        for url in list_img_urls:
            if url.endswith((".jpg", ".png")):
                image_uuid += 1
                image_file_name = f"{title}_{url.split('/')[-1]}"
                image_file_path = image_path / f"{image_uuid}.jpg"

                image_metadata_dict[image_uuid] = {"filename": image_file_name, "img_path": str(image_file_path)}
                urllib.request.urlretrieve(url, image_file_path)
                images_per_wiki += 1
                if images_per_wiki >= MAX_IMAGES_PER_WIKI:
                    break
    except Exception as e:
        print(f"Error retrieving images for Wikipedia page: {title}. {e}")
        continue
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Step 3: Parse Wikipedia Images and Load into Local Folder
# ----> 3 import wikipedia
#       4 import urllib.request
#       5 import os
#
# ModuleNotFoundError: No module named 'wikipedia'

# %%
# Step 4: Set Up API Key for Groq

import os
from dotenv import load_dotenv

# Load environment variables from .env
load_dotenv()

# Access the GROQ_API_KEY
api_key = os.getenv('GROQ_API_KEY')

# %%
# Step 5: Build Multi-Modal Vector Store Using Text and Image Embeddings Under Different Collections

import groq_client
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex, StorageContext
from llama_index.vector_stores.qdrant import QdrantVectorStore
from llama_index.core.indices import MultiModalVectorStoreIndex

client = qdrant_client.QdrantClient(path="qdrant_d_0")

text_store = QdrantVectorStore(client=client, collection_name="text_collection_0")
image_store = QdrantVectorStore(client=client, collection_name="image_collection_0")
storage_context = StorageContext.from_defaults(vector_store=text_store, image_store=image_store)

# Load documents from local directory
documents = SimpleDirectoryReader("./data_wiki/").load_data()

# Create a MultiModal index
index = MultiModalVectorStoreIndex.from_documents(documents, storage_context=storage_context)

# %%
# Step 6: Plot Downloaded Images from Wikipedia

from PIL import Image
import matplotlib.pyplot as plt

def plot_images(image_metadata_dict, max_images=64):
    plt.figure(figsize=(16, 16))
    for idx, image_id in enumerate(image_metadata_dict):
        if idx >= max_images:
            break
        img_path = image_metadata_dict[image_id]["img_path"]
        if os.path.isfile(img_path):
            image = Image.open(img_path).convert("RGB")
            plt.subplot(8, 8, idx + 1)
            plt.imshow(image)
            plt.xticks([])
            plt.yticks([])

    plt.tight_layout()
    plt.show()

plot_images(image_metadata_dict)

# %%
# Step 7: Get Multi-Modal Retrieval Results for Some Example Queries

from llama_index.core.response.notebook_utils import display_source_node
from llama_index.core.schema import ImageNode

def retrieve_and_plot(query, top_k_text=3, top_k_image=5):
    # Use Groq API to get text embeddings
    text_embeddings = groq_client.get_text_embeddings(query)
    
    # Use CLIP to get image embeddings
    retriever = index.as_retriever(similarity_top_k=top_k_text, image_similarity_top_k=top_k_image)
    retrieval_results = retriever.retrieve(query)
    
    retrieved_image = []
    for res_node in retrieval_results:
        if isinstance(res_node.node, ImageNode):
            retrieved_image.append(res_node.node.metadata["file_path"])
        else:
            display_source_node(res_node, source_length=200)

    plot_images(retrieved_image)

# %%
# Example queries
queries = [
    "What is the Labour Party?",
    "Who created RoboCop?",
    "What does OpenAI do?",
    "Which company makes Tesla?"
]

for query in queries:
    retrieve_and_plot(query)
